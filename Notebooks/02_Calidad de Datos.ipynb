# %% [markdown]
# # CALIDAD DE DATOS

# %% [markdown]
# ## IMPORTAR PAQUETES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from dotenv import load_dotenv
import os
from pathlib import Path
import openpyxl
import sqlalchemy as sa

# Desactivar notación científica
pd.set_option('display.float_format', lambda x: '%.3f' % x)
np.set_printoptions(suppress=True)

# Cargar variables de entorno
load_dotenv()

print("✅ Librerías importadas correctamente")
# Out:
# ✅ Librerías importadas correctamente

# %% [markdown]
# ## IMPORTAR LOS DATOS

# %%
df = pd.read_pickle('../02_datos/03_Entrenamiento/train.pkl')
df
# Out:
#         id_cliente                               empleo antigüedad_empleo  \
# 0        137387967                     Hvac technician            3 years
# 1          4798121  Target Promotions and Marketing,Inc         10+ years
# 2         46641215                               Banker           5 years
# 3         87998444                   executive director           9 years
# 4        132883631                    Subsea Technician           7 years
# ...            ...                                  ...               ...
# 199992    73222117                  Executive Assistant         10+ years
# 199995    51876926                       Office Manager         10+ years
# 199996   121031962                    Owner & President           6 years
# 199998    53664762                             Attorney           8 years
# 199999    94394801                                  NaN               NaN
#
#          ingresos ingresos_verificados rating    dti  vivienda  num_hipotecas  \
# 0       54000.000      Source Verified      A 19.310  MORTGAGE          2.000
# 1       65000.000         Not Verified      D 25.400      RENT          1.000
# 2      135000.000             Verified      A 14.680      RENT          0.000
# 3      188000.000      Source Verified      B 11.690  MORTGAGE          3.000
# 4      125000.000      Source Verified      B  9.000  MORTGAGE          1.000
# ...           ...                  ...    ...    ...       ...            ...
# 199992  85000.000             Verified      B 33.050      RENT          1.000
# 199995  42000.000         Not Verified      C 20.850  MORTGAGE          6.000
# 199996 111697.000             Verified      B 16.630  MORTGAGE          2.000
# 199998 168000.000      Source Verified      E  4.690      RENT          0.000
# 199999  80000.000         Not Verified      C 31.490  MORTGAGE          1.000
#
#         num_lineas_credito  ...  id_prestamo  descripcion           finalidad  \
# 0                   10.000  ...          NaN          NaN  debt_consolidation
# 1                   15.000  ...          NaN          NaN  debt_consolidation
# 2                   19.000  ...          NaN          NaN  debt_consolidation
# 3                   15.000  ...          NaN          NaN         credit_card
# 4                    6.000  ...          NaN          NaN  debt_consolidation
# ...                    ...  ...          ...          ...                 ...
# 199992              25.000  ...          NaN          NaN  debt_consolidation
# 199995               9.000  ...          NaN          NaN  debt_consolidation
# 199996              10.000  ...          NaN          NaN               other
# 199998               8.000  ...          NaN          NaN      small_business
# 199999               9.000  ...          NaN          NaN  debt_consolidation
#
#         principal  tipo_interes  num_cuotas imp_cuota imp_amortizado  \
# 0       15000.000         7.210   36 months   464.600       2669.060
# 1       10000.000        17.770   36 months   360.380       6362.960
# 2       24000.000         6.390   36 months   734.380      24000.000
# 3       27000.000         8.990   60 months   560.350      12443.000
# 4       22000.000        10.900   36 months   719.220      22000.000
# ...           ...           ...         ...       ...            ...
# 199992   3000.000         9.750   36 months    96.450       3000.000
# 199995   8000.000        12.290   36 months   266.830       8000.000
# 199996  10000.000         9.440   36 months   320.050       4388.510
# 199998  30050.000        18.250   60 months   767.170       2964.440
# 199999  10000.000        13.990   36 months   341.730       7096.400
#
#              estado  imp_recuperado
# 0           Current           0.000
# 1       Charged Off           0.000
# 2        Fully Paid           0.000
# 3           Current           0.000
# 4        Fully Paid           0.000
# ...             ...             ...
# 199992   Fully Paid           0.000
# 199995   Fully Paid           0.000
# 199996      Current           0.000
# 199998  Charged Off        2750.880
# 199999      Current           0.000
#
# [140000 rows x 25 columns]

# %%
# Eliminar el índice del DataFrame
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## VISIÓN GENERAL

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 140000 entries, 0 to 139999
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id_cliente                   140000 non-null  int64
#  1   empleo                       129596 non-null  str
#  2   antigüedad_empleo            130914 non-null  str
#  3   ingresos                     140000 non-null  float64
#  4   ingresos_verificados         140000 non-null  str
#  5   rating                       140000 non-null  str
#  6   dti                          139895 non-null  float64
#  7   vivienda                     140000 non-null  str
#  8   num_hipotecas                136873 non-null  float64
#  9   num_lineas_credito           139998 non-null  float64
#  10  porc_tarjetas_75p            135341 non-null  float64
#  11  porc_uso_revolving           139893 non-null  float64
#  12  num_cancelaciones_12meses    139992 non-null  float64
#  13  num_derogatorios             139998 non-null  float64
#  14  num_meses_desde_ult_retraso  68231 non-null   float64
#  15  id_prestamo                  0 non-null       float64
#  16  descripcion                  7801 non-null    str
#  17  finalidad                    140000 non-null  str
#  18  principal                    140000 non-null  float64
#  19  tipo_interes                 140000 non-null  float64
#  20  num_cuotas                   140000 non-null  str
#  21  imp_cuota                    140000 non-null  float64
#  22  imp_amortizado               140000 non-null  float64
#  23  estado                       140000 non-null  str
#  24  imp_recuperado               140000 non-null  float64
# dtypes: float64(15), int64(1), str(9)
# memory usage: 38.5 MB

# %% [markdown]
# ## TIPOS DE DATOS

# %% [markdown]
# ### Identificación

# %%
df.head().T
# Out:
#                                               0  \
# id_cliente                            137387967
# empleo                         Hvac technician
# antigüedad_empleo                       3 years
# ingresos                              54000.000
# ingresos_verificados            Source Verified
# rating                                        A
# dti                                      19.310
# vivienda                               MORTGAGE
# num_hipotecas                             2.000
# num_lineas_credito                       10.000
# porc_tarjetas_75p                        33.300
# porc_uso_revolving                       45.200
# num_cancelaciones_12meses                 0.000
# num_derogatorios                          0.000
# num_meses_desde_ult_retraso              10.000
# id_prestamo                                 NaN
# descripcion                                 NaN
# finalidad                    debt_consolidation
# principal                             15000.000
# tipo_interes                              7.210
# num_cuotas                            36 months
# imp_cuota                               464.600
# imp_amortizado                         2669.060
# estado                                  Current
# imp_recuperado                            0.000
#
#                                                                1  \
# id_cliente                                               4798121
# empleo                       Target Promotions and Marketing,Inc
# antigüedad_empleo                                      10+ years
# ingresos                                               65000.000
# ingresos_verificados                                Not Verified
# rating                                                         D
# dti                                                       25.400
# vivienda                                                    RENT
# num_hipotecas                                              1.000
# num_lineas_credito                                        15.000
# porc_tarjetas_75p                                         85.700
# porc_uso_revolving                                        86.200
# num_cancelaciones_12meses                                  0.000
# num_derogatorios                                           0.000
# num_meses_desde_ult_retraso                                  NaN
# id_prestamo                                                  NaN
# descripcion                                                  NaN
# finalidad                                     debt_consolidation
# principal                                              10000.000
# tipo_interes                                              17.770
# num_cuotas                                             36 months
# imp_cuota                                                360.380
# imp_amortizado                                          6362.960
# estado                                               Charged Off
# imp_recuperado                                             0.000
#
#                                               2                   3  \
# id_cliente                             46641215            87998444
# empleo                                   Banker  executive director
# antigüedad_empleo                       5 years             9 years
# ingresos                             135000.000          188000.000
# ingresos_verificados                   Verified     Source Verified
# rating                                        A                   B
# dti                                      14.680              11.690
# vivienda                                   RENT            MORTGAGE
# num_hipotecas                             0.000               3.000
# num_lineas_credito                       19.000              15.000
# porc_tarjetas_75p                         0.000               0.000
# porc_uso_revolving                       16.300               3.300
# num_cancelaciones_12meses                 0.000               0.000
# num_derogatorios                          0.000               0.000
# num_meses_desde_ult_retraso                 NaN                 NaN
# id_prestamo                                 NaN                 NaN
# descripcion                                 NaN                 NaN
# finalidad                    debt_consolidation         credit_card
# principal                             24000.000           27000.000
# tipo_interes                              6.390               8.990
# num_cuotas                            36 months           60 months
# imp_cuota                               734.380             560.350
# imp_amortizado                        24000.000           12443.000
# estado                               Fully Paid             Current
# imp_recuperado                            0.000               0.000
#
#                                               4
# id_cliente                            132883631
# empleo                        Subsea Technician
# antigüedad_empleo                       7 years
# ingresos                             125000.000
# ingresos_verificados            Source Verified
# rating                                        B
# dti                                       9.000
# vivienda                               MORTGAGE
# num_hipotecas                             1.000
# num_lineas_credito                        6.000
# porc_tarjetas_75p                        33.300
# porc_uso_revolving                       69.900
# num_cancelaciones_12meses                 0.000
# num_derogatorios                          0.000
# num_meses_desde_ult_retraso              16.000
# id_prestamo                                 NaN
# descripcion                                 NaN
# finalidad                    debt_consolidation
# principal                             22000.000
# tipo_interes                             10.900
# num_cuotas                            36 months
# imp_cuota                               719.220
# imp_amortizado                        22000.000
# estado                               Fully Paid
# imp_recuperado                            0.000

# %%
df.dtypes
# Out:
# id_cliente                       int64
# empleo                             str
# antigüedad_empleo                  str
# ingresos                       float64
# ingresos_verificados               str
# rating                             str
# dti                            float64
# vivienda                           str
# num_hipotecas                  float64
# num_lineas_credito             float64
# porc_tarjetas_75p              float64
# porc_uso_revolving             float64
# num_cancelaciones_12meses      float64
# num_derogatorios               float64
# num_meses_desde_ult_retraso    float64
# id_prestamo                    float64
# descripcion                        str
# finalidad                          str
# principal                      float64
# tipo_interes                   float64
# num_cuotas                         str
# imp_cuota                      float64
# imp_amortizado                 float64
# estado                             str
# imp_recuperado                 float64
# dtype: object

# %% [markdown]
# Conclusiones:
#
# * num_hipotecas, num_lineas_credito, num_cancelaciones_12meses, num_derogatorios, num_meses_desde_ult_retraso deberían ser int
# * pero vemos que hay nulos, así que no podemos convertirlas hasta que los imputemos

# %% [markdown]
# ## VALORES ÚNICOS

# %% [markdown]
# ### Identificación

# %%
df.nunique().sort_values()
# Out:
# id_prestamo                         0
# num_cuotas                          2
# ingresos_verificados                3
# vivienda                            6
# num_cancelaciones_12meses           7
# rating                              7
# estado                              9
# antigüedad_empleo                  11
# finalidad                          14
# num_derogatorios                   18
# num_hipotecas                      25
# num_lineas_credito                 62
# num_meses_desde_ult_retraso       131
# porc_tarjetas_75p                 170
# tipo_interes                      588
# porc_uso_revolving               1096
# principal                        1472
# dti                              5310
# descripcion                      7779
# imp_recuperado                  10643
# ingresos                        11563
# imp_cuota                       33575
# empleo                          54538
# imp_amortizado                  57678
# id_cliente                     140000
# dtype: int64

# %% [markdown]
# Conclusiones:
#
# * id_prestamo con menos de 2 valores --> eliminar

# %% [markdown]
# ### Corrección

# %%
df.drop(columns = 'id_prestamo', inplace = True)

# %% [markdown]
# ## DUPLICADOS

# %% [markdown]
# ### Identificación

# %%
df.duplicated(subset='id_cliente').sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## SEPARAR NUMÉRICAS Y CATEGÓRICAS

# %% [markdown]
# ### Categóricas

# %%
cat = df.select_dtypes(exclude = 'number').copy()

# %% [markdown]
# ### Numéricas

# %%
num = df.select_dtypes(include='number').copy()

# %% [markdown]
# ## GESTIÓN DE CATEGÓRICAS

# %% [markdown]
# ### Nulos

# %% [markdown]
# #### Identificación

# %%
cat.isna().sum().sort_values(ascending = False)
# Out:
# descripcion             132199
# empleo                   10404
# antigüedad_empleo         9086
# rating                       0
# ingresos_verificados         0
# vivienda                     0
# finalidad                    0
# num_cuotas                   0
# estado                       0
# dtype: int64

# %%
cat.descripcion.value_counts(dropna=False)
# Out:
# descripcion
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     132199
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             15
#   Borrower added on 02/25/14 > Debt Consolidation<br>                                                                                                                                                                                                                                                                                                                                                                                                                                        2
#   Borrower added on 10/07/13 > Debt consolidation<br>                                                                                                                                                                                                                                                                                                                                                                                                                                        2
#   Borrower added on 12/08/12 > Debt Consolidation<br>                                                                                                                                                                                                                                                                                                                                                                                                                                        2
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
#   Borrower added on 06/12/12 > Credit card refinancing<br>                                                                                                                                                                                                                                                                                                                                                                                                                                   1
#   Borrower added on 10/16/13 > Loan consolidation<br>                                                                                                                                                                                                                                                                                                                                                                                                                                        1
#   Borrower added on 01/13/10 > Steady job required degree and experience for me and my wife. Combined we gross 135,000/year we are able to pay this loan back with no discrepencies.<br/>                                                                                                                                                                                                                                                                                                    1
#   Borrower added on 03/17/14 > During my lifetime I've  lived like most Americans. I've borrowed my way to things I believed I needed to impress people I didn't even like. That changed a few years back when I took a class and realized I had to pay off my debt. I want 1 payment but will budget to pay extra on the loan.<br>                                                                                                                                                          1
#   Borrower added on 11/01/11 > Looking to use this loan to repay my large credit card debits.  I have always paid all of my debt payments on time, and am trying to get out from underneath all of this credit card debt now.  I have an extremely safe job as I work for a very conservative international mutual fund company, which I have been employed by for 5 years now.  Please let me know if you would like any further information about this loan.<br/><br/>Thanks!<br/>         1
# Name: count, Length: 7780, dtype: int64

# %%
cat.empleo.value_counts(dropna=False)
# Out:
# empleo
# NaN                             10404
# Teacher                          2428
# Manager                          2173
# Owner                            1376
# Registered Nurse                 1000
#                                 ...
# ILT Inc                             1
# Unified Strategies Group            1
# TMS Domain Manager                  1
# Immigration Senior Paralegal        1
# Owner & President                   1
# Name: count, Length: 54539, dtype: int64

# %%
cat.empleo.nunique()
# Out:
# 54538

# %%
cat.antigüedad_empleo.value_counts(dropna=False)
# Out:
# antigüedad_empleo
# 10+ years    46067
# 2 years      12471
# < 1 year     11894
# 3 years      11260
# 1 year        9105
# NaN           9086
# 5 years       8674
# 4 years       8547
# 6 years       6342
# 7 years       5849
# 8 years       5756
# 9 years       4949
# Name: count, dtype: int64

# %% [markdown]
# Conclusiones:
#
# * eliminar descripción y empleo
# * imputar nulos de antigüedad_empleo por valor 'desconocido'

# %% [markdown]
# #### Corrección

# %%
# eliminar descripción y empleo
cat.drop(columns = ['descripcion', 'empleo'], inplace = True)

# %%
# imputar nulos de antigüedad_empleo por valor 'desconocido'
cat['antigüedad_empleo'] = cat['antigüedad_empleo'].fillna('desconocido')

# %% [markdown]
# ## GESTIÓN DE NUMÉRICAS

# %% [markdown]
# ### Nulos

# %% [markdown]
# #### Identificación

# %%
num.isna().sum().sort_values(ascending = False)
# Out:
# num_meses_desde_ult_retraso    71769
# porc_tarjetas_75p               4659
# num_hipotecas                   3127
# porc_uso_revolving               107
# dti                              105
# num_cancelaciones_12meses          8
# num_lineas_credito                 2
# num_derogatorios                   2
# ingresos                           0
# id_cliente                         0
# principal                          0
# tipo_interes                       0
# imp_cuota                          0
# imp_amortizado                     0
# imp_recuperado                     0
# dtype: int64

# %% [markdown]
# Veamoslas con más detalle.

# %%
num.num_meses_desde_ult_retraso.value_counts(dropna=False).sort_index()
# Out:
# num_meses_desde_ult_retraso
# 0.000        185
# 1.000        439
# 2.000        626
# 3.000        800
# 4.000        965
#            ...
# 148.000        1
# 151.000        1
# 159.000        1
# 195.000        1
# NaN        71769
# Name: count, Length: 132, dtype: int64

# %% [markdown]
# Hay ceros, pero parecen pocos para una variable que implica retrasos.
#
# Así que vamos a pensar que los nulos significan que no ha habido retrasos.
#
# Y por tanto imputar por ceros.

# %%
num.porc_tarjetas_75p.value_counts(dropna=False).sort_index()
# Out:
# porc_tarjetas_75p
# 0.000      36788
# 0.170          1
# 0.330          1
# 0.500          3
# 0.570          1
#            ...
# 94.400         3
# 94.700         1
# 95.000         1
# 100.000    23251
# NaN         4659
# Name: count, Length: 171, dtype: int64

# %% [markdown]
# ¿Los 4659 nulos significa que no tienen tarjeta?
# La categoría mayoritaria es cero, asi que imput0 por cero.

# %%
num.num_hipotecas.value_counts(dropna=False).sort_index()
# Out:
# num_hipotecas
# 0.000     57547
# 1.000     24466
# 2.000     20042
# 3.000     14404
# 4.000      9232
# 5.000      5354
# 6.000      2911
# 7.000      1466
# 8.000       708
# 9.000       347
# 10.000      176
# 11.000       82
# 12.000       42
# 13.000       32
# 14.000       24
# 15.000       11
# 16.000        7
# 17.000        8
# 18.000        8
# 19.000        1
# 20.000        1
# 21.000        1
# 25.000        1
# 27.000        1
# 32.000        1
# NaN        3127
# Name: count, dtype: int64

# %% [markdown]
# Conclusiones:
#
# * imputar todas por ceros

# %% [markdown]
# #### Corrección

# %%
num.fillna(0,inplace=True)
# Out:
#         id_cliente   ingresos    dti  num_hipotecas  num_lineas_credito  \
# 0        137387967  54000.000 19.310          2.000              10.000
# 1          4798121  65000.000 25.400          1.000              15.000
# 2         46641215 135000.000 14.680          0.000              19.000
# 3         87998444 188000.000 11.690          3.000              15.000
# 4        132883631 125000.000  9.000          1.000               6.000
# ...            ...        ...    ...            ...                 ...
# 139995    73222117  85000.000 33.050          1.000              25.000
# 139996    51876926  42000.000 20.850          6.000               9.000
# 139997   121031962 111697.000 16.630          2.000              10.000
# 139998    53664762 168000.000  4.690          0.000               8.000
# 139999    94394801  80000.000 31.490          1.000               9.000
#
#         porc_tarjetas_75p  porc_uso_revolving  num_cancelaciones_12meses  \
# 0                  33.300              45.200                      0.000
# 1                  85.700              86.200                      0.000
# 2                   0.000              16.300                      0.000
# 3                   0.000               3.300                      0.000
# 4                  33.300              69.900                      0.000
# ...                   ...                 ...                        ...
# 139995             90.000              76.000                      1.000
# 139996            100.000              81.600                      0.000
# 139997             50.000              26.300                      0.000
# 139998              0.000              52.400                      0.000
# 139999             50.000              49.100                      0.000
#
#         num_derogatorios  num_meses_desde_ult_retraso  principal  \
# 0                  0.000                       10.000  15000.000
# 1                  0.000                        0.000  10000.000
# 2                  0.000                        0.000  24000.000
# 3                  0.000                        0.000  27000.000
# 4                  0.000                       16.000  22000.000
# ...                  ...                          ...        ...
# 139995             0.000                        0.000   3000.000
# 139996             0.000                       13.000   8000.000
# 139997             1.000                        6.000  10000.000
# 139998             2.000                        0.000  30050.000
# 139999             0.000                       49.000  10000.000
#
#         tipo_interes  imp_cuota  imp_amortizado  imp_recuperado
# 0              7.210    464.600        2669.060           0.000
# 1             17.770    360.380        6362.960           0.000
# 2              6.390    734.380       24000.000           0.000
# 3              8.990    560.350       12443.000           0.000
# 4             10.900    719.220       22000.000           0.000
# ...              ...        ...             ...             ...
# 139995         9.750     96.450        3000.000           0.000
# 139996        12.290    266.830        8000.000           0.000
# 139997         9.440    320.050        4388.510           0.000
# 139998        18.250    767.170        2964.440        2750.880
# 139999        13.990    341.730        7096.400           0.000
#
# [140000 rows x 15 columns]

# %% [markdown]
# Ya habiendo imputado los ceros podemos cambiar los tipos a int, para que ocupen menos memoria.

# %%
# meter num_hipotecas, num_lineas_credito, num_cancelaciones_12meses, num_derogatorios, num_meses_desde_ult_retraso en una lista y cambiar su tipo a entero
num_imputar_ceros = ['num_hipotecas', 'num_lineas_credito', 'num_cancelaciones_12meses', 'num_derogatorios', 'num_meses_desde_ult_retraso']
num[num_imputar_ceros] = num[num_imputar_ceros].astype(int)

# %%
num.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 140000 entries, 0 to 139999
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id_cliente                   140000 non-null  int64
#  1   ingresos                     140000 non-null  float64
#  2   dti                          140000 non-null  float64
#  3   num_hipotecas                140000 non-null  int64
#  4   num_lineas_credito           140000 non-null  int64
#  5   porc_tarjetas_75p            140000 non-null  float64
#  6   porc_uso_revolving           140000 non-null  float64
#  7   num_cancelaciones_12meses    140000 non-null  int64
#  8   num_derogatorios             140000 non-null  int64
#  9   num_meses_desde_ult_retraso  140000 non-null  int64
#  10  principal                    140000 non-null  float64
#  11  tipo_interes                 140000 non-null  float64
#  12  imp_cuota                    140000 non-null  float64
#  13  imp_amortizado               140000 non-null  float64
#  14  imp_recuperado               140000 non-null  float64
# dtypes: float64(9), int64(6)
# memory usage: 16.0 MB

# %% [markdown]
# ### Atípicos

# %% [markdown]
# #### Por desviación típica

# %% [markdown]
# ##### Identificación

# %%
num_desv_tip = 4

# %% [markdown]
# Función que devuelve los índices de los atípicos

# %%
def atipicos_desv_tip(variable, num_desv_tip = 4):
    #sacamos los nulos por ahora
    variable = variable.dropna()
    #calculamos los límites
    media = np.mean(variable)
    sd = np.std(variable)
    umbral = sd * num_desv_tip
    lim_inf = media - umbral
    lim_sup = media + umbral
    #encontramos los índices de los que están fuera de los límites
    indices = [indice for indice,valor in variable.items() if valor < lim_inf or valor > lim_sup]
    return(indices)

# %% [markdown]
# Función que cuenta el número de atípicos

# %%
def conteo_atipicos(df,variable, num_desv_tip = 4):
    atipicos = atipicos_desv_tip(df[variable], num_desv_tip)
    return(df.loc[atipicos,variable].value_counts().sort_index())

# %% [markdown]
# Variables a aplicar

# %%
var_atipicos_dt = ['ingresos','principal','imp_cuota','imp_recuperado']

# %% [markdown]
# Obtener los 10 primeros atipicos ordenados en cada variable

# %%
for variable in var_atipicos_dt:
    print('\n' + variable + ':\n')
    conteo = conteo_atipicos(num, variable, num_desv_tip)
    print(conteo.sort_index().head(10))
# Out:
# ingresos:
#
# ingresos
# 415000.000    6
# 418000.000    1
# 420000.000    7
# 422000.000    1
# 423000.000    2
# 425000.000    8
# 426000.000    1
# 427000.000    1
# 430000.000    3
# 431000.000    1
# Name: count, dtype: int64
#
# principal:
#
# Series([], Name: count, dtype: int64)
#
# imp_cuota:
#
# imp_cuota
# 1535.710    1
# 1566.800    2
# 1587.020    1
# 1607.800    1
# 1714.540    1
# Name: count, dtype: int64
#
# imp_recuperado:
#
# imp_recuperado
# 3227.430    1
# 3227.610    1
# 3228.090    1
# 3228.490    1
# 3228.600    1
# 3228.760    1
# 3229.080    1
# 3231.130    1
# 3231.660    1
# 3231.980    1
# Name: count, dtype: int64

# %% [markdown]
# Revisamos con más detalle la variable ingresos.

# %%
num.ingresos.describe()
# Out:
# count    140000.000
# mean      78295.673
# std       83346.194
# min           0.000
# 25%       46499.750
# 50%       65000.000
# 75%       93600.000
# max     9573072.000
# Name: ingresos, dtype: float64

# %% [markdown]
# ##### Corrección

# %% [markdown]
# Eliminar los registros con ingresos superiores a 400.000$

# %% [markdown]
# *Si se eliminan registros hay que eliminarlos tanto de cat como de num*

# %% [markdown]
# ###### Id de registros a eliminar

# %%
a_eliminar = num.loc[num.ingresos > 400000].index.values
a_eliminar
# Out:
# array([   270,   1238,   1701,   1780,   1816,   3602,   4004,   4145,
#          4462,   4569,   4584,   5236,   5258,   5897,   6322,   7163,
#          7470,   7719,   8302,   8442,   8598,   8795,   9029,   9165,
#          9679,   9847,  10289,  10649,  10865,  11122,  11368,  11454,
#         11653,  11917,  12603,  12894,  12975,  13356,  13393,  13505,
#         14201,  14790,  15469,  15567,  15629,  16002,  16320,  16364,
#         16395,  16457,  16746,  16947,  17016,  17203,  17208,  17480,
#         18072,  18564,  18622,  20035,  20355,  20543,  20743,  20902,
#         21018,  21086,  21551,  21674,  21944,  22472,  22715,  22751,
#         22794,  23551,  23556,  23625,  24139,  24422,  24471,  24546,
#         24689,  24793,  25503,  25548,  25687,  25894,  26260,  26334,
#         26604,  26783,  26973,  27606,  28387,  28437,  28614,  28954,
#         29068,  29247,  29765,  30171,  30205,  30306,  30359,  30994,
#         31033,  31478,  31624,  31782,  32622,  33412,  34414,  34877,
#         35172,  35518,  36429,  36652,  37073,  37096,  37724,  37731,
#         38351,  38727,  39287,  42049,  42087,  42153,  42328,  42702,
#         43047,  43157,  43212,  43651,  44093,  44795,  44873,  45147,
#         45616,  46407,  46700,  47240,  48378,  48879,  49167,  49210,
#         49644,  49676,  50004,  51030,  51194,  51484,  51566,  51955,
#         52447,  52697,  53013,  53035,  53279,  53446,  53453,  53875,
#         54140,  54966,  55093,  55361,  55381,  55531,  56295,  56885,
#         56911,  57227,  57258,  57618,  58480,  58703,  58713,  58864,
#         58919,  59012,  59647,  59899,  59964,  60867,  61349,  61470,
#         62469,  62514,  62612,  62668,  62916,  63170,  64017,  64326,
#         64407,  65077,  65810,  66900,  66943,  67504,  68228,  68691,
#         68849,  68888,  69394,  69970,  70860,  71189,  71367,  71803,
#         71955,  72004,  72335,  73177,  73735,  74146,  75248,  75547,
#         75695,  75812,  75923,  76020,  76299,  76346,  76630,  77978,
#         78623,  78904,  80363,  80579,  81073,  81904,  81981,  82310,
#         82584,  83595,  83701,  83755,  84172,  84187,  84384,  84611,
#         84695,  85128,  85237,  85414,  85942,  86069,  86344,  86594,
#         86609,  87042,  87826,  89098,  89849,  90542,  91044,  91220,
#         91400,  91635,  91904,  92873,  92982,  93402,  93571,  93841,
#         94874,  95348,  95556,  95869,  96465,  96569,  96627,  96712,
#         96805,  97078,  97231,  97802,  98074,  98108,  98185,  98373,
#         98521,  98561,  98687,  99407,  99954, 100007, 101089, 101303,
#        101309, 101358, 101991, 103186, 103769, 103793, 104618, 105387,
#        106155, 106503, 107031, 107050, 107165, 107243, 107417, 107636,
#        108809, 109397, 110044, 110197, 110547, 110827, 110877, 111577,
#        111740, 112290, 112516, 112823, 112929, 113005, 113282, 113555,
#        113992, 114103, 114214, 114279, 114537, 114674, 114687, 114836,
#        114936, 115686, 115978, 117354, 117451, 117566, 118029, 119062,
#        119117, 120410, 120467, 120524, 120739, 120854, 120938, 121212,
#        122050, 122318, 122518, 123497, 123521, 123612, 123775, 123824,
#        123947, 124859, 125048, 125532, 126024, 126341, 126873, 127598,
#        128229, 128582, 128723, 128804, 128950, 129018, 129257, 129557,
#        129650, 129694, 129892, 130064, 130299, 130822, 131335, 131349,
#        132366, 132443, 132502, 132856, 133251, 133407, 134066, 134253,
#        134310, 134401, 135747, 136462, 136999, 137076, 137265, 137275,
#        137706, 138326, 139320, 139638, 139668])

# %%
cat = cat[~cat.index.isin(a_eliminar)]
num = num[~num.index.isin(a_eliminar)]

# %% [markdown]
# ## GUARDAR DATASETS TRAS CALIDAD DE DATOS

# %% [markdown]
# Guarda los avances en df, cat y num con un sufijo para poder guardar o recuperar avances del proyecto.
#
# En formato pickle para no perder las modificaciones de metadatos.

# %%
df.to_pickle('../02_datos/03_Entrenamiento/train_calidad.pkl')
cat.to_pickle('../02_datos/03_Entrenamiento/cat_calidad.pkl')
num.to_pickle('../02_datos/03_Entrenamiento/num_calidad.pkl')
